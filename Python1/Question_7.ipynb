# %%
 import pandas as pd
import numpy as np
import requests
import json
import logging

# Configure logging
logging.basicConfig(filename='question_7_log.txt', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Requesting content from the URL with GET method
response = requests.get('https://data.nasa.gov/resource/y77d-th95.json')

# Check if the request was successful
if response.status_code == 200:
    # Extract the JSON data
    json_data = response.json()

    # Save the JSON data to a file
    with open('json_data.json', 'w') as json_file:
        json.dump(json_data, json_file)
    logging.info("JSON data has been saved successfully.")
else:
    logging.error("Error occurred while requesting the data.")

# Load JSON data
with open('json_data.json') as json_file:
    data = json.load(json_file)

# Convert JSON data to a DataFrame
structured_dataset = pd.json_normalize(data)

# Rename columns
old_columns = ['name', 'id', 'nametype', 'recclass', 'mass', 'year', 'reclat', 'reclong', 'geolocation.coordinates']
new_columns = ['Name', 'Id', 'Nametype', 'Recclass', 'Mass', 'Year', 'Reclat', 'Reclong', 'Pointer Coordinates']
structured_dataset.columns=structured_dataset.columns.map(dict(zip(old_columns,new_columns)))
# Drop Irrelevant columns 
structured_dataset.drop(np.nan,axis=1,inplace=True)

# Convert data types
structured_dataset['Mass'] = structured_dataset['Mass'].astype(float)
structured_dataset['Id'] = structured_dataset['Id'].astype(int)
structured_dataset['Year'] = structured_dataset['Year'].apply(lambda x: int(x[:4]) if isinstance(x, str) else 0)
structured_dataset['Reclat'] = structured_dataset['Reclat'].astype(float)
structured_dataset['Reclong'] = structured_dataset['Reclong'].astype(float)

# Save the DataFrame as an Excel file
structured_dataset.to_excel('structured_dataset.xlsx', index=False)
logging.info("Structured dataset has been saved as structured_dataset.xlsx.")

# %%
df=structured_dataset.copy()

# %%
df.head()
# Out:
#        Name   Id Nametype     Recclass      Mass  Year    Reclat    Reclong  \
# 0    Aachen    1    Valid           L5      21.0  1880  50.77500    6.08333
# 1    Aarhus    2    Valid           H6     720.0  1951  56.18333   10.23333
# 2      Abee    6    Valid          EH4  107000.0  1952  54.21667 -113.00000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976  16.88333  -99.90000
# 4   Achiras  370    Valid           L6     780.0  1902 -33.16667  -64.95000
#
#     Pointer Coordinates
# 0     [6.08333, 50.775]
# 1  [10.23333, 56.18333]
# 2      [-113, 54.21667]
# 3     [-99.9, 16.88333]
# 4   [-64.95, -33.16667]

# %%
df.shape
# Out:
# (1000, 9)

# %%
#Question 1: Get all the Earth meteorites that fell before the year 2000.

meteorites_that_fell_before_the_year_2000=df[df['Year']<2000].dropna()

print(f'''all the Earth meteorites that fell before the year 2000.
{meteorites_that_fell_before_the_year_2000['Mass'].count()}

''')
# Out:
# all the Earth meteorites that fell before the year 2000.
# 894

# %%
# Create a folium map centered on a specific location
map = folium.Map(location=[meteorites_that_fell_before_the_year_2000['Reclat'].mean(), meteorites_that_fell_before_the_year_2000['Reclong'].mean()], zoom_start=2)

# Add markers for each coordinate in the subset
for _, row in meteorites_that_fell_before_the_year_2000.iterrows():
    folium.Marker(location=[row['Reclat'], row['Reclong']], popup=row['Name']).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c78b5abfe124cc78c77c8d420cc2f2f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c78b5abfe124cc78c77c8d420cc2f2f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c78b5abfe124cc78c77c8d420cc2f2f3 = L.map(
#                 &quot;map_c78b5abfe124cc78c77c8d420cc2f2f3&quot;,
#                 {
#                     center: [30.019166677852347, 20.82471449664429],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6c797b374fd212a15eb8d93e76c664c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#             var marker_aa1eadf67990741225dfe1a1c56fba8e = L.marker(
#                 [50.775, 6.08333],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#         var popup_4d607612f5ff64c0ef91869b5eecaa96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0b37299f3d1fd7640d5d05d9c59d0e9 = $(`&lt;div id=&quot;html_c0b37299f3d1fd7640d5d05d9c59d0e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aachen&lt;/div&gt;`)[0];
#                 popup_4d607612f5ff64c0ef91869b5eecaa96.setContent(html_c0b37299f3d1fd7640d5d05d9c59d0e9);
#
#
#
#         marker_aa1eadf67990741225dfe1a1c56fba8e.bindPopup(popup_4d607612f5ff64c0ef91869b5eecaa96)
#         ;
#
#
#
#
#             var marker_aa8319c7928ff974af9654d24650afa7 = L.marker(
#                 [56.18333, 10.23333],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#         var popup_8741d6cd1f60ecd7364bffa2b349350b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ebe8d09b0c348700d6ef39ec1d0f77a = $(`&lt;div id=&quot;html_1ebe8d09b0c348700d6ef39ec1d0f77a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aarhus&lt;/div&gt;`)[0];
#                 popup_8741d6cd1f60ecd7364bffa2b349350b.setContent(html_1ebe8d09b0c348700d6ef39ec1d0f77a);
#
#
#
#         marker_aa8319c7928ff974af9654d24650afa7.bindPopup(popup_8741d6cd1f60ecd7364bffa2b349350b)
#         ;
#
#
#
#
#             var marker_480d30ce1cbd1967fa785b7e68449adb = L.marker(
#                 [54.21667, -113.0],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#         var popup_96f1887783ccb4a7824a2c491048ec1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eeb872a883ca9e638450d4bd868847f3 = $(`&lt;div id=&quot;html_eeb872a883ca9e638450d4bd868847f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abee&lt;/div&gt;`)[0];
#                 popup_96f1887783ccb4a7824a2c491048ec1f.setContent(html_eeb872a883ca9e638450d4bd868847f3);
#
#
#
#         marker_480d30ce1cbd1967fa785b7e68449adb.bindPopup(popup_96f1887783ccb4a7824a2c491048ec1f)
#         ;
#
#
#
#
#             var marker_fee70c3697010b889282972fbf72ddb5 = L.marker(
#                 [16.88333, -99.9],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#         var popup_6e0daf43c4ab46ccedd3278683474900 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c08211fce6230132dee63e931337d5fb = $(`&lt;div id=&quot;html_c08211fce6230132dee63e931337d5fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acapulco&lt;/div&gt;`)[0];
#                 popup_6e0daf43c4ab46ccedd3278683474900.setContent(html_c08211fce6230132dee63e931337d5fb);
#
#
#
#         marker_fee70c3697010b889282972fbf72ddb5.bindPopup(popup_6e0daf43c4ab46ccedd3278683474900)
#         ;
#
#
#
#
#             var marker_b60c1bc9bc0764893fddf2457bb47b98 = L.marker(
#                 [-33.16667, -64.95],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c8d420cc2f2f3);
#
#
#         var popup_23d83894b16e91b4414f31d12d16518a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc3bc58b943e28325c962a18c886bd3e = $(`&lt;div id=&quot;html_cc3bc58b943e28325c962a18c886bd3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Achiras&lt;/div&gt;`)[0];
#                 popup_23d83894b16e91b4414f31d12d16518a.setContent(html_cc3bc58b943e28325c962a18c886bd3e);
#
#
#
#         marker_b60c1bc9bc0764893fddf2457bb47b98.bindPopup(popup_23d83894b16e91b4414f31d12d16518a)
#         ;
#
#
#
#
#             var marker_b18aa3862bed2a9754ef7755b2f8394a = L.marker(
#                 [32.1, 71.8],
#                 {}
#             ).addTo(map_c78b5abfe124cc78c77c

# %%
#Question 2: Get all the Earth meteorites' coordinates that fell before the year 1970.

earth_meteorites_before_1970=df[df['Year']<1970]['Pointer Coordinates'].dropna()

print(''' Earth meteorites' coordinates that fell before the year 1970.''')
print(len(earth_meteorites_before_1970))
# Out:
#  Earth meteorites' coordinates that fell before the year 1970.
# 775

# %%
import folium
# Select a subset of coordinates (e.g., first 1000)
subset_coordinates = earth_meteorites_before_1970

# Create a folium map centered on a specific location
map = folium.Map(location=[subset_coordinates[4][0], subset_coordinates[4][1]], zoom_start=2)

# Add markers for each coordinate in the subset
for row in subset_coordinates:
    folium.Marker(location=row).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05e0d4adb806d42ea21fe9905b8081e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05e0d4adb806d42ea21fe9905b8081e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05e0d4adb806d42ea21fe9905b8081e4 = L.map(
#                 &quot;map_05e0d4adb806d42ea21fe9905b8081e4&quot;,
#                 {
#                     center: [-64.95, -33.16667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07ae3f4b9a0bbd47b6bbf67411a0b256 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_0628bdbc24e17f01c4b679b62bd620f8 = L.marker(
#                 [6.08333, 50.775],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_a5dd7107e665f9eadbd23192f711d2b1 = L.marker(
#                 [10.23333, 56.18333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_a58a828473fb5d0e85e98c0730c6144c = L.marker(
#                 [-113.0, 54.21667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_5aad90b17d73988846efdb3ffc0d22b9 = L.marker(
#                 [-64.95, -33.16667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_2e2ee71fce549faf521edcd299d7b551 = L.marker(
#                 [71.8, 32.1],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_237ffc0f40cd5313c7669b34da9fddb9 = L.marker(
#                 [95.16667, 44.83333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_82d9329aa6bb1a64ed2c33f505fb3e03 = L.marker(
#                 [0.61667, 44.21667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_50b8cbc564d3eb9ef5371f7233d2a865 = L.marker(
#                 [-65.23333, -31.6],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_5ec7246eaad5eb369c7a54d0a463d8b9 = L.marker(
#                 [-64.55, -30.86667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_12205e4abb15d4d3592c184b443c280f = L.marker(
#                 [8.38333, 19.08333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_d5ed2599f55a8ce2041dc873b956d266 = L.marker(
#                 [2.33333, 50.66667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_af228ec55b5477f6971cf50fa989298b = L.marker(
#                 [35.05, 29.51667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_bcfd485d9285fbdbbf983eadbca9a24a = L.marker(
#                 [77.95, 29.71667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_71527711bb15a586199614adc53addc2 = L.marker(
#                 [8.43333, 8.91667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_f9dfe6aa306877ae5f1538c4d659e107 = L.marker(
#                 [39.51667, 24.41667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_204fa1ccaa1f207d04cde769e380243c = L.marker(
#                 [4.08333, 44.11667],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_43dc8b603bddb1a98091f2a1d1c3294b = L.marker(
#                 [11.01667, 44.65],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_b07e1d73607a01760d41fb1b0a7aadb4 = L.marker(
#                 [22.66667, 2.0],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_26a86e310a6d3f09e4bce9759deaaa50 = L.marker(
#                 [-1.78333, 51.78333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_63ebb0c4313e01619e5a66a06d98ab8d = L.marker(
#                 [37.13333, 36.23333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21fe9905b8081e4);
#
#
#             var marker_9e3d3f15512d4d34f857d157dc119f68 = L.marker(
#                 [8.75, 44.88333],
#                 {}
#             ).addTo(map_05e0d4adb806d42ea21f

# %%
Mass_greater_than_10000=df[df['Mass']>10000]
print('mass of the earth meteorites more than 10000kg')
print(Mass_greater_than_10000['Name'].count())
# Out:
# mass of the earth meteorites more than 10000kg
# 243

# %%
# Create a folium map centered on a specific location
map = folium.Map(location=[Mass_greater_than_10000['Reclat'].mean(), Mass_greater_than_10000['Reclong'].mean()], zoom_start=2)

# Add markers for each coordinate in the subset
for _, row in Mass_greater_than_10000.iterrows():
    folium.Marker(location=[row['Reclat'], row['Reclong']], popup=row['Name']).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6c3652ae8564e7eb019506b47743c55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6c3652ae8564e7eb019506b47743c55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6c3652ae8564e7eb019506b47743c55 = L.map(
#                 &quot;map_b6c3652ae8564e7eb019506b47743c55&quot;,
#                 {
#                     center: [31.5986604526749, 18.516927613168725],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daf512a178851d421b7ccc9f6d41f5d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#             var marker_8da6bf509a49af2567bde96b85fb117d = L.marker(
#                 [54.21667, -113.0],
#                 {}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#         var popup_1cbca19e319db2292662980c66eac965 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12bd0cb1e4635795dc60b4aafd4965f2 = $(`&lt;div id=&quot;html_12bd0cb1e4635795dc60b4aafd4965f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abee&lt;/div&gt;`)[0];
#                 popup_1cbca19e319db2292662980c66eac965.setContent(html_12bd0cb1e4635795dc60b4aafd4965f2);
#
#
#
#         marker_8da6bf509a49af2567bde96b85fb117d.bindPopup(popup_1cbca19e319db2292662980c66eac965)
#         ;
#
#
#
#
#             var marker_9b6bf9f39aea8e67723207a0d6fd4157 = L.marker(
#                 [44.21667, 0.61667],
#                 {}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#         var popup_5f8e3c28a84b2aa56b13b30259779a61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71524c7a2342ebfc7a2c41ef14ea24d5 = $(`&lt;div id=&quot;html_71524c7a2342ebfc7a2c41ef14ea24d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agen&lt;/div&gt;`)[0];
#                 popup_5f8e3c28a84b2aa56b13b30259779a61.setContent(html_71524c7a2342ebfc7a2c41ef14ea24d5);
#
#
#
#         marker_9b6bf9f39aea8e67723207a0d6fd4157.bindPopup(popup_5f8e3c28a84b2aa56b13b30259779a61)
#         ;
#
#
#
#
#             var marker_bad4c99de7b93610f76b63e790bbbc57 = L.marker(
#                 [19.08333, 8.38333],
#                 {}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#         var popup_45a552d2d65180742edd6db47c8e6707 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04d0c41939ea6c3e346ad72019d5a9ef = $(`&lt;div id=&quot;html_04d0c41939ea6c3e346ad72019d5a9ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aïr&lt;/div&gt;`)[0];
#                 popup_45a552d2d65180742edd6db47c8e6707.setContent(html_04d0c41939ea6c3e346ad72019d5a9ef);
#
#
#
#         marker_bad4c99de7b93610f76b63e790bbbc57.bindPopup(popup_45a552d2d65180742edd6db47c8e6707)
#         ;
#
#
#
#
#             var marker_194a5f7cba44e40e70cd899d28f93e65 = L.marker(
#                 [39.91667, 42.81667],
#                 {}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#         var popup_09980c0b1f03eef3d209ac435c1dde15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13b591380b616ff0d96beb3c44e907aa = $(`&lt;div id=&quot;html_13b591380b616ff0d96beb3c44e907aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Akyumak&lt;/div&gt;`)[0];
#                 popup_09980c0b1f03eef3d209ac435c1dde15.setContent(html_13b591380b616ff0d96beb3c44e907aa);
#
#
#
#         marker_194a5f7cba44e40e70cd899d28f93e65.bindPopup(popup_09980c0b1f03eef3d209ac435c1dde15)
#         ;
#
#
#
#
#             var marker_4d50ace53df73d5b543e6ecd95c86373 = L.marker(
#                 [45.26667, 10.15],
#                 {}
#             ).addTo(map_b6c3652ae8564e7eb019506b47743c55);
#
#
#         var popup_ad4920f2277eacb7140dabecf4cf9b66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38fc002541e7a86e48a09d9867cda5a3 = $(`&lt;div id=&quot;html_38fc002541e7a86e48a09d9867cda5a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alfianello&lt;/div&gt;`)[0];
#                 popup_ad4920f2277eacb7140dabecf4cf9b66.setContent(html_38fc002541e7a86e48a09d9867cda5a3);
#
#
#
#         marker_4d50ace53df73d5b543e6ecd95c86373.bindPopup(popup_ad4920f2277eacb7140dabecf4cf9b66)
#         ;
#
#
#
#
#             var marker_5456a2da90a2d07df41ce8180ca6f822 = L.marker(
#                 [42.53333, -85.88333],
#                 {}
#             ).addTo(map_b6c3652ae8564
